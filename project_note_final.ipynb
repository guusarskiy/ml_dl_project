# %% [markdown]
# ## Реализация LSTM

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from torchmetrics import MeanSquaredError, R2Score
import time
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# %% [markdown]
# ### Готовим данные

# %%
market_data = pd.read_csv('C:/Projects/vsCode/ml_unik_project/data/market_project_data_usd.csv', sep=',')
market_data.tail()
# Out:
#                  timestamp  btc_open  btc_high   btc_low  btc_close  \
# 29001  2024-10-28 06:00:00  67904.98  67960.84  67796.96   67960.84
# 29002  2024-10-28 07:00:00  67960.84  68687.24  67960.83   68422.86
# 29003  2024-10-28 08:00:00  68422.86  68601.25  68319.72   68319.73
# 29004  2024-10-28 09:00:00  68319.73  68613.46  68234.50   68567.38
# 29005  2024-10-28 10:00:00  68567.38  68840.35  68540.79   68626.36
#
#          btc_volume    btc_rsi    btc_macd  btc_macd_signal  btc_macd_hist  \
# 29001  2.126584e+07  61.089602  149.857681       161.277091     -11.419409
# 29002  6.663986e+07  70.811992  187.464076       166.514488      20.949588
# 29003  4.146691e+07  66.799715  206.564537       174.524498      32.040040
# 29004  3.743416e+07  71.042774  238.930830       187.405764      51.525066
# 29005  4.522336e+07  71.961822  266.271136       203.178838      63.092297
#
#        btc_slowK  btc_slowD     btc_atr  eth_open  eth_high  eth_low  \
# 29001  41.529205  34.515670  248.548729   2486.39   2491.58  2482.21
# 29002  58.815671  43.949671  282.681677   2491.58   2527.35  2490.85
# 29003  65.985977  55.443618  282.599414   2511.61   2521.34  2509.44
# 29004  77.894878  67.565509  289.482313   2513.00   2542.71  2505.25
# 29005  79.783399  74.554751  290.202148   2542.04   2545.04  2529.26
#
#        eth_close    eth_volume  fear_greed    eth_rsi  eth_macd  \
# 29001    2491.58  1.699042e+07        72.0  51.240606  1.623511
# 29002    2511.61  3.303710e+07        72.0  60.837478  3.122860
# 29003    2513.00  1.957421e+07        72.0  61.405178  4.372858
# 29004    2542.04  2.804183e+07        72.0  70.897049  7.618949
# 29005    2531.14  2.580878e+07        72.0  64.486353  9.205842
#
#        eth_macd_signal  eth_macd_hist  eth_slowK  eth_slowD    eth_atr  \
# 29001         3.403689      -1.780178  29.590458  24.128223  14.104938
# 29002         3.347523      -0.224663  44.538457  31.799753  15.704585
# 29003         3.552590       0.820268  60.173923  44.767613  15.432829
# 29004         4.365862       3.253087  81.255087  61.989156  17.006198
# 29005         5.333858       3.871984  84.599693  75.342901  16.918613
#
#        fed_rate
# 29001      4.83
# 29002      4.83
# 29003      4.83
# 29004      4.83
# 29005      4.83

# %%
market_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29006 entries, 0 to 29005
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestamp        29006 non-null  object
#  1   btc_open         29006 non-null  float64
#  2   btc_high         29006 non-null  float64
#  3   btc_low          29006 non-null  float64
#  4   btc_close        29006 non-null  float64
#  5   btc_volume       29006 non-null  float64
#  6   btc_rsi          29006 non-null  float64
#  7   btc_macd         29006 non-null  float64
#  8   btc_macd_signal  29006 non-null  float64
#  9   btc_macd_hist    29006 non-null  float64
#  10  btc_slowK        29006 non-null  float64
#  11  btc_slowD        29006 non-null  float64
#  12  btc_atr          29006 non-null  float64
#  13  eth_open         29006 non-null  float64
#  14  eth_high         29006 non-null  float64
#  15  eth_low          29006 non-null  float64
#  16  eth_close        29006 non-null  float64
#  17  eth_volume       29006 non-null  float64
#  18  fear_greed       29006 non-null  float64
#  19  eth_rsi          29006 non-null  float64
#  20  eth_macd         29006 non-null  float64
#  21  eth_macd_signal  29006 non-null  float64
#  22  eth_macd_hist    29006 non-null  float64
#  23  eth_slowK        29006 non-null  float64
#  24  eth_slowD        29006 non-null  float64
#  25  eth_atr          29006 non-null  float64
#  26  fed_rate         29006 non-null  float64
# dtypes: float64(26), object(1)
# memory usage: 6.0+ MB

# %% [markdown]
# #### Можем удалить timestamp, т.к. данные уже отсортированы

# %%
market_data = market_data.drop(['timestamp'], axis=1)
market_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29006 entries, 0 to 29005
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   btc_open         29006 non-null  float64
#  1   btc_high         29006 non-null  float64
#  2   btc_low          29006 non-null  float64
#  3   btc_close        29006 non-null  float64
#  4   btc_volume       29006 non-null  float64
#  5   btc_rsi          29006 non-null  float64
#  6   btc_macd         29006 non-null  float64
#  7   btc_macd_signal  29006 non-null  float64
#  8   btc_macd_hist    29006 non-null  float64
#  9   btc_slowK        29006 non-null  float64
#  10  btc_slowD        29006 non-null  float64
#  11  btc_atr          29006 non-null  float64
#  12  eth_open         29006 non-null  float64
#  13  eth_high         29006 non-null  float64
#  14  eth_low          29006 non-null  float64
#  15  eth_close        29006 non-null  float64
#  16  eth_volume       29006 non-null  float64
#  17  fear_greed       29006 non-null  float64
#  18  eth_rsi          29006 non-null  float64
#  19  eth_macd         29006 non-null  float64
#  20  eth_macd_signal  29006 non-null  float64
#  21  eth_macd_hist    29006 non-null  float64
#  22  eth_slowK        29006 non-null  float64
#  23  eth_slowD        29006 non-null  float64
#  24  eth_atr          29006 non-null  float64
#  25  fed_rate         29006 non-null  float64
# dtypes: float64(26)
# memory usage: 5.8 MB

# %%
plt.plot(market_data['eth_close'])
plt.show()

# %% [markdown]
# #### train | test

# %%
train_size = int(0.75 * len(market_data))
test_size = len(market_data) - train_size 

train_data = market_data[:train_size]
test_data = market_data[train_size:]

print('size of train df: ', train_data.shape)
print('size of test df: ', test_data.shape)
# Out:
# size of train df:  (21754, 26)
# size of test df:  (7252, 26)

# %% [markdown]
# #### Нормализация MixMaxScaler()

# %%
y_col = 'eth_close'
X_cols = [col for col in train_data.columns if col != y_col]

train_data = train_data.copy()
test_data = test_data.copy()

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

train_data[X_cols] = scaler_X.fit_transform(train_data[X_cols])
train_data[y_col] = scaler_y.fit_transform(train_data[[y_col]])

test_data[X_cols] = scaler_X.transform(test_data[X_cols])
test_data[y_col] = scaler_y.transform(test_data[[y_col]])

# %%
test_data.tail()
# Out:
#        btc_open  btc_high   btc_low  btc_close  btc_volume   btc_rsi  \
# 29001  0.987301  0.981082  0.987947   0.988357    0.077967  0.641721
# 29002  0.988357  0.994737  0.991042   0.997087    0.244330  0.753902
# 29003  0.997087  0.993121  0.997819   0.995139    0.152034  0.707606
# 29004  0.995139  0.993350  0.996210   0.999818    0.137248  0.756564
# 29005  0.999818  0.997615  1.001994   1.000933    0.165807  0.767169
#
#        btc_macd  btc_macd_signal  btc_macd_hist  btc_slowK  btc_slowD  \
# 29001  0.689794         0.692881       0.598078   0.403437   0.337257
# 29002  0.700216         0.694515       0.626393   0.580578   0.436954
# 29003  0.705509         0.697014       0.636095   0.654055   0.558421
# 29004  0.714478         0.701034       0.653140   0.776091   0.686523
# 29005  0.722055         0.705956       0.663258   0.795443   0.760385
#
#         btc_atr  eth_open  eth_high   eth_low  eth_close  eth_volume  \
# 29001  0.166073  0.401363  0.397379  0.405253   0.402680    0.112719
# 29002  0.190260  0.402680  0.406466  0.407440   0.407762    0.219178
# 29003  0.190201  0.407762  0.404939  0.412144   0.408114    0.129861
# 29004  0.195079  0.408114  0.410368  0.411084   0.415482    0.186038
# 29005  0.195589  0.415482  0.410959  0.417160   0.412717    0.171223
#
#        fear_greed   eth_rsi  eth_macd  eth_macd_signal  eth_macd_hist  \
# 29001    0.846154  0.526295  0.619930         0.631782       0.604254
# 29002    0.846154  0.636032  0.625948         0.631533       0.619878
# 29003    0.846154  0.642523  0.630965         0.632444       0.630373
# 29004    0.846154  0.751060  0.643992         0.636060       0.654808
# 29005    0.846154  0.677756  0.650361         0.640364       0.661025
#
#        eth_slowK  eth_slowD   eth_atr  fed_rate
# 29001   0.278552   0.215435  0.111974  0.904762
# 29002   0.432272   0.295510  0.126300  0.904762
# 29003   0.593061   0.430866  0.123866  0.904762
# 29004   0.809851   0.610623  0.137956  0.904762
# 29005   0.844246   0.750007  0.137172  0.904762

# %% [markdown]
# #### Создание временных окон

# %%
class TimeSeriesDataset(Dataset):
    def __init__(self, data, target_column, sequence_length=24):
        self.data = data
        self.target_column = target_column
        self.sequence_length = sequence_length

    def __len__(self):
        return len(self.data) - self.sequence_length

    def __getitem__(self, idx):
        X = self.data.iloc[idx:idx + self.sequence_length].drop(columns=[self.target_column]).values
        
        y = self.data.iloc[idx + self.sequence_length][self.target_column]
        
        return torch.tensor(X, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)

# %%
sequence_length = 24
target_column = 'eth_close'  

train_dataset = TimeSeriesDataset(train_data, target_column, sequence_length)
test_dataset = TimeSeriesDataset(test_data, target_column, sequence_length)

X, y = train_dataset[0]
print(f"X shape: {X.shape}, y shape: {y.shape}")                                                           
print("len train: ", len(train_dataset))
# Out:
# X shape: torch.Size([24, 25]), y shape: torch.Size([])
# len train:  21730

# %%
BATCH_SIZE = 32

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

for batch_idx, (x_batch, y_batch) in enumerate(train_loader):
    print(f"batch {batch_idx}| shape X: {x_batch.shape}, shape y: {y_batch.shape}")
    break
# Out:
# batch 0| shape X: torch.Size([32, 24, 25]), shape y: torch.Size([32])

# %% [markdown]
# ### Строим модель

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"device: {device}")
# Out:
# device: cuda

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, fc_size, output_size, dropout_rate=0.2):
        super(LSTMModel, self).__init__()
        
        # 1st LSTM
        self.lstm1 = nn.LSTM(input_size, hidden_size1, batch_first=True)
        self.dropout1 = nn.Dropout(dropout_rate)
        
        # 2nd LSTM
        self.lstm2 = nn.LSTM(hidden_size1, hidden_size2, batch_first=True)
        self.dropout2 = nn.Dropout(dropout_rate)
        
        # Linears
        self.fc1 = nn.Linear(hidden_size2, fc_size)  
        self.sigmoid = nn.Sigmoid()  
        self.fc2 = nn.Linear(fc_size, output_size)  
        
    
    def forward(self, x):
        out, _ = self.lstm1(x)
        out = self.dropout1(out)
        
        out, _ = self.lstm2(out)
        out = self.dropout2(out)

        out = out[:, -1, :]  
        
        out = self.fc1(out)  
        out = self.sigmoid(out)  
        out = self.fc2(out)  
        
        return out

# %%
input_size = 25   
hidden_size1 = 48  
hidden_size2 = 24  
fc_size = 16      
output_size = 1     
dropout_rate = 0.4
num_epochs = 100
learning_rate = 0.001

model = LSTMModel(input_size, hidden_size1, hidden_size2, fc_size, output_size, dropout_rate).to(device)
print(model)
# Out:
# LSTMModel(
#   (lstm1): LSTM(25, 48, batch_first=True)
#   (dropout1): Dropout(p=0.4, inplace=False)
#   (lstm2): LSTM(48, 24, batch_first=True)
#   (dropout2): Dropout(p=0.4, inplace=False)
#   (fc1): Linear(in_features=24, out_features=16, bias=True)
#   (sigmoid): Sigmoid()
#   (fc2): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
loss_fn = nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
X_example = torch.rand(BATCH_SIZE, sequence_length, input_size).to(device)

y_pred = model(X_example)
print(f"output shape: {y_pred.shape}")
# Out:
# output shape: torch.Size([32, 1])

# %% [markdown]
# ### Обучаем модель

# %%
def train_model(model_nn, train_loader, test_loader, optimizer, loss_fn, num_epochs, device):
    train_r2 = R2Score().to(device)
    test_r2 = R2Score().to(device)
    
    for epoch in range(num_epochs):
        start = time.time()
        
        train_loss = 0.0
        train_iters = 0
        
        model_nn.train()
        
        for X, y in train_loader:
            X, y = X.to(device), y.to(device)  
            y = y.unsqueeze(-1)  
            
            y_pred = model_nn(X)  
            
            optimizer.zero_grad()  
            loss = loss_fn(y_pred, y)  
            loss.backward()  
            optimizer.step()  
            
            train_loss += loss.item()  
            train_iters += 1
            
            train_r2.update(y_pred, y)
        
        train_r2_out = train_r2.compute()
        train_r2.reset()

        test_loss = 0.0
        test_iters = 0
        
        model_nn.eval()
        
        with torch.no_grad():  
            for X, y in test_loader:
                X, y = X.to(device), y.to(device)  
                y = y.unsqueeze(-1)  
                
                y_pred = model_nn(X)  
                
                loss = loss_fn(y_pred, y)  
                
                test_loss += loss.item()  
                test_iters += 1
                
                test_r2.update(y_pred, y)
        
        test_r2_out = test_r2.compute()
        test_r2.reset()

        if (epoch < 9):
            print(f"Эпоха: 0{epoch+1} | Время: {time.time()-start:.2f} сек | "
              f"Train Loss: {train_loss/train_iters:.4f} | Train R²: {train_r2_out:.2f} | "
              f"Test Loss: {test_loss/test_iters:.4f} | Test R²: {test_r2_out:.2f}")
        else:
            print(f"Эпоха: {epoch+1} | Время: {time.time()-start:.2f} сек | "
                f"Train Loss: {train_loss/train_iters:.4f} | Train R²: {train_r2_out:.2f} | "
                f"Test Loss: {test_loss/test_iters:.4f} | Test R²: {test_r2_out:.2f}")

# %%
train_model(model, train_loader, test_loader, optimizer, loss_fn, num_epochs, device)
# Out:
# Эпоха: 01 | Время: 12.96 сек | Train Loss: 0.0064 | Train R²: 0.88 | Test Loss: 0.0449 | Test R²: -1.76
# Эпоха: 02 | Время: 12.92 сек | Train Loss: 0.0052 | Train R²: 0.90 | Test Loss: 0.0454 | Test R²: -1.80
# Эпоха: 03 | Время: 13.03 сек | Train Loss: 0.0058 | Train R²: 0.89 | Test Loss: 0.0457 | Test R²: -1.82
# Эпоха: 04 | Время: 12.92 сек | Train Loss: 0.0060 | Train R²: 0.88 | Test Loss: 0.0457 | Test R²: -1.82
# Эпоха: 05 | Время: 12.75 сек | Train Loss: 0.0062 | Train R²: 0.88 | Test Loss: 0.0458 | Test R²: -1.82
# Эпоха: 06 | Время: 12.94 сек | Train Loss: 0.0063 | Train R²: 0.88 | Test Loss: 0.0470 | Test R²: -1.89
# Эпоха: 07 | Время: 13.02 сек | Train Loss: 0.0073 | Train R²: 0.86 | Test Loss: 0.0497 | Test R²: -2.06
# Эпоха: 08 | Время: 13.07 сек | Train Loss: 0.0076 | Train R²: 0.85 | Test Loss: 0.0475 | Test R²: -1.93
# Эпоха: 09 | Время: 13.13 сек | Train Loss: 0.0059 | Train R²: 0.89 | Test Loss: 0.0470 | Test R²: -1.90
# Эпоха: 10 | Время: 13.13 сек | Train Loss: 0.0068 | Train R²: 0.87 | Test Loss: 0.0484 | Test R²: -1.98
# Эпоха: 11 | Время: 13.17 сек | Train Loss: 0.0069 | Train R²: 0.87 | Test Loss: 0.0454 | Test R²: -1.80
# Эпоха: 12 | Время: 13.22 сек | Train Loss: 0.0060 | Train R²: 0.88 | Test Loss: 0.0475 | Test R²: -1.93
# Эпоха: 13 | Время: 13.19 сек | Train Loss: 0.0052 | Train R²: 0.90 | Test Loss: 0.0470 | Test R²: -1.89
# Эпоха: 14 | Время: 13.07 сек | Train Loss: 0.0045 | Train R²: 0.91 | Test Loss: 0.0452 | Test R²: -1.78
# Эпоха: 15 | Время: 13.07 сек | Train Loss: 0.0041 | Train R²: 0.92 | Test Loss: 0.0423 | Test R²: -1.60
# Эпоха: 16 | Время: 13.08 сек | Train Loss: 0.0039 | Train R²: 0.92 | Test Loss: 0.0402 | Test R²: -1.48
# Эпоха: 17 | Время: 13.05 сек | Train Loss: 0.0037 | Train R²: 0.93 | Test Loss: 0.0371 | Test R²: -1.29
# Эпоха: 18 | Время: 12.96 сек | Train Loss: 0.0035 | Train R²: 0.93 | Test Loss: 0.0321 | Test R²: -0.98
# Эпоха: 19 | Время: 12.98 сек | Train Loss: 0.0032 | Train R²: 0.94 | Test Loss: 0.0281 | Test R²: -0.73
# Эпоха: 20 | Время: 13.05 сек | Train Loss: 0.0029 | Train R²: 0.94 | Test Loss: 0.0223 | Test R²: -0.38
# Эпоха: 21 | Время: 13.03 сек | Train Loss: 0.0028 | Train R²: 0.95 | Test Loss: 0.0180 | Test R²: -0.11
# Эпоха: 22 | Время: 13.03 сек | Train Loss: 0.0026 | Train R²: 0.95 | Test Loss: 0.0146 | Test R²: 0.10
# Эпоха: 23 | Время: 13.08 сек | Train Loss: 0.0025 | Train R²: 0.95 | Test Loss: 0.0118 | Test R²: 0.27
# Эпоха: 24 | Время: 12.94 сек | Train Loss: 0.0024 | Train R²: 0.95 | Test Loss: 0.0096 | Test R²: 0.41
# Эпоха: 25 | Время: 13.01 сек | Train Loss: 0.0023 | Train R²: 0.96 | Test Loss: 0.0082 | Test R²: 0.49
# Эпоха: 26 | Время: 13.05 сек | Train Loss: 0.0023 | Train R²: 0.96 | Test Loss: 0.0069 | Test R²: 0.58
# Эпоха: 27 | Время: 13.06 сек | Train Loss: 0.0022 | Train R²: 0.96 | Test Loss: 0.0063 | Test R²: 0.61
# Эпоха: 28 | Время: 13.09 сек | Train Loss: 0.0022 | Train R²: 0.96 | Test Loss: 0.0060 | Test R²: 0.63
# Эпоха: 29 | Время: 12.98 сек | Train Loss: 0.0021 | Train R²: 0.96 | Test Loss: 0.0060 | Test R²: 0.63
# Эпоха: 30 | Время: 13.19 сек | Train Loss: 0.0021 | Train R²: 0.96 | Test Loss: 0.0067 | Test R²: 0.59
# Эпоха: 31 | Время: 13.08 сек | Train Loss: 0.0020 | Train R²: 0.96 | Test Loss: 0.0067 | Test R²: 0.59
# Эпоха: 32 | Время: 12.84 сек | Train Loss: 0.0021 | Train R²: 0.96 | Test Loss: 0.0066 | Test R²: 0.60
# Эпоха: 33 | Время: 12.91 сек | Train Loss: 0.0019 | Train R²: 0.96 | Test Loss: 0.0070 | Test R²: 0.57
# Эпоха: 34 | Время: 13.04 сек | Train Loss: 0.0020 | Train R²: 0.96 | Test Loss: 0.0075 | Test R²: 0.54
# Эпоха: 35 | Время: 13.03 сек | Train Loss: 0.0020 | Train R²: 0.96 | Test Loss: 0.0117 | Test R²: 0.28
# Эпоха: 36 | Время: 12.99 сек | Train Loss: 0.0019 | Train R²: 0.96 | Test Loss: 0.0082 | Test R²: 0.50
# Эпоха: 37 | Время: 13.00 сек | Train Loss: 0.0019 | Train R²: 0.96 | Test Loss: 0.0104 | Test R²: 0.36
# Эпоха: 38 | Время: 13.03 сек | Train Loss: 0.0018 | Train R²: 0.97 | Test Loss: 0.0122 | Test R²: 0.25
# Эпоха: 39 | Время: 13.09 сек | Train Loss: 0.0018 | Train R²: 0.97 | Test Loss: 0.0112 | Test R²: 0.31
# Эпоха: 40 | Время: 12.46 сек | Train Loss: 0.0017 | Train R²: 0.97 | Test Loss: 0.0129 | Test R²: 0.21
# Эпоха: 41 | Время: 12.80 сек | Train Loss: 0.0017 | Train R²: 0.97 | Test Loss: 0.0115 | Test R²: 0.29
# Эпоха: 42 | Время: 13.05 сек | Train Loss: 0.0017 | Train R²: 0.97 | Test Loss: 0.0120 | Test R²: 0.26
# Эпоха: 43 | Время: 13.12 сек | Train Loss: 0.0016 | Train R²: 0.97 | Test Loss: 0.0133 | Test R²: 0.18
# Эпоха: 44 | Время: 13.10 сек | Train Loss: 0.0015 | Train R²: 0.97 | Test Loss: 0.0129 | Test R²: 0.21
# Эпоха: 45 | Время: 13.02 сек | Train Loss: 0.0015 | Train R²: 0.97 | Test Loss: 0.0124 | Test R²: 0.24
# Эпоха: 46 | Время: 13.02 сек | Train Loss: 0.0015 | Train R²: 0.97 | Test Loss: 0.0123 | Test R²: 0.25
# Эпоха: 47 | Время: 12.98 сек | Train Loss: 0.0015 | Train R²: 0.97 | Test Loss: 0.0123 | Test R²: 0.25
# Эпоха: 48 | Время: 13.02 сек | Train Loss: 0.0014 | Train R²: 0.97 | Test Loss: 0.0130 | Test R²: 0.20
# Эпоха: 49 | Время: 13.03 сек | Train Loss: 0.0014 | Train R²: 0.97 | Test Loss: 0.0106 | Test R²: 0.35
# Эпоха: 50 | Время: 13.03 сек | Train Loss: 0.0014 | Train R²: 0.97 | Test Loss: 0.0128 | Test R²: 0.22
# Эпоха: 51 | Время: 12.81 сек | Train Loss: 0.0014 | Train R²: 0.97 | Test Loss: 0.0108 | Test R²: 0.34
# Эпоха: 52 | Время: 12.81 сек | Train Loss: 0.0012 | Train R²: 0.98 | Test Loss: 0.0120 | Test R²: 0.26
# Эпоха: 53 | Время: 12.68 сек | Train Loss: 0.0013 | Train R²: 0.97 | Test Loss: 0.0113 | Test R²: 0.30
# Эпоха: 54 | Время: 12.86 сек | Train Loss: 0.0012 | Train R²: 0.98 | Test Loss: 0.0099 | Test R²: 0.39
# Эпоха: 55 | Время: 13.04 сек | Train Loss: 0.0012 | Train R²: 0.98 | Test Loss: 0.0111 | Test R²: 0.32
# Эпоха: 56 | Время: 12.79 сек | Train Loss: 0.0011 | Train R²: 0.98 | Test Loss: 0.0111 | Test R²: 0.32
# Эпоха: 57 | Время: 13.05 сек | Train Loss: 0.0012 | Train R²: 0.98 | Test Loss: 0.0111 | Test R²: 0.32
# Эпоха: 58 | Время: 13.06 сек | Train Loss: 0.0011 | Train R²: 0.98 | Test Loss: 0.0091 | Test R²: 0.44
# Эпоха: 59 | Время: 13.01 сек | Train Loss: 0.0011 | Train R²: 0.98 | Test Loss: 0.0088 | Test R²: 0.46
# Эпоха: 60 | Время: 12.95 сек | Train Loss: 0.0011 | Train R²: 0.98 | Test Loss: 0.0089 | Test R²: 0.45
# Эпоха: 61 | Время: 12.95 сек | Train Loss: 0.0010 | Train R²: 0.98 | Test Loss: 0.0079 | Test R²: 0.51
# Эпоха: 62 | Время: 13.00 сек | Train Loss: 0.0010 | Train R²: 0.98 | Test Loss: 0.0086 | Test R²: 0.47
# Эпоха: 63 | Время: 12.91 сек | Train Loss: 0.0010 | Train R²: 0.98 | Test Loss: 0.0082 | Test R²: 0.50
# Эпоха: 64 | Время: 13.05 сек | Train Loss: 0.0010 | Train R²: 0.98 | Test Loss: 0.0078 | Test R²: 0.52
# Эпоха: 65 | Время: 13.12 сек | Train Loss: 0.0010 | Train R²: 0.98 | Test Loss: 0.0068 | Test R²: 0.58
# Эпоха: 66 | Время: 13.12 сек | Train Loss: 0.0009 | Train R²: 0.98 | Test Loss: 0.0064 | Test R²: 0.61
# Эпоха: 67 | Время: 12.98 сек | Train Loss: 0.0010 | Train R²: 0.98 | Test Loss: 0.0064 | Test R²: 0.61
# Эпоха: 68 | Время: 13.00 сек | Train Loss: 0.0009 | Train R²: 0.98 | Test Loss: 0.0051 | Test R²: 0.68
# Эпоха: 69 | Время: 13.10 сек | Train Loss: 0.0009 | Train R²: 0.98 | Test Loss: 0.0059 | Test R²: 0.64
# Эпоха: 70 | Время: 13.03 сек | Train Loss: 0.0009 | Train R²: 0.98 | Test Loss: 0.0060 | Test R²: 0.63
# Эпоха: 71 | Время: 13.01 сек | Train Loss: 0.0009 | Train R²: 0.98 | Test Loss: 0.0062 | Test R²: 0.62
# Эпоха: 72 | Время: 13.15 сек | Train Loss: 0.0009 | Train R²: 0.98 | Test Loss: 0.0053 | Test R²: 0.67
# Эпоха: 73 | Время: 13.13 сек | Train Loss: 0.0009 | Train R²: 0.98 | Test Loss: 0.0055 | Test R²: 0.66
# Эпоха: 74 | Время: 13.09 сек | Train Loss: 0.0009 | Train R²: 0.98 | Test Loss: 0.0044 | Test R²: 0.73
# Эпоха: 75 | Время: 13.03 сек | Train Loss: 0.0009 | Train R²: 0.98 | Test Loss: 0.0062 | Test R²: 0.62
# Эпоха: 76 | Время: 13.01 сек | Train Loss: 0.0008 | Train R²: 0.98 | Test Loss: 0.0055 | Test R²: 0.66
# Эпоха: 77 | Время: 12.92 сек | Train Loss: 0.0008 | Train R²: 0.98 | Test Loss: 0.0063 | Test R²: 0.62
# Эпоха: 78 | Время: 12.90 сек | Train Loss: 0.0008 | Train R²: 0.98 | Test Loss: 0.0044 | Test R²: 0.73
# Эпоха: 79 | Время: 12.87 сек | Train Loss: 0.0008 | Train R²: 0.98 | Test Loss: 0.0043 | Test R²: 0.73
# Эпоха: 80 | Время: 12.98 сек | Train Loss: 0.0008 | Train R²: 0.99 | Test Loss: 0.0052 | Test R²: 0.68
# Эпоха: 81 | Время: 12.98 сек | Train Loss: 0.0008 | Train R²: 0.98 | Test Loss: 0.0052 | Test R²: 0.68
# Эпоха: 82 | Время: 12.92 сек | Train Loss: 0.0008 | Train R²: 0.99 | Test Loss: 0.0037 | Test R²: 0.77
# Эпоха: 83 | Время: 12.92 сек | Train Loss: 0.0008 | Train R²: 0.99 | Test Loss: 0.0038 | Test R²: 0.77
# Эпоха: 84 | Время: 13.09 сек | Train Loss: 0.0007 | Train R²: 0.99 | Test Loss: 0.0049 | Test R²: 0.70
# Эпоха: 85 | Время: 13.00 сек | Train Loss: 0.0008 | Train R²: 0.99 | Test Loss: 0.0049 | Test R²: 0.70
# Эпоха: 86 | Время: 13.05 сек | Train Loss: 0.0007 | Train R²: 0.99 | Test Loss: 0.0038 | Test R²: 0.76
# Эпоха: 87 | Время: 13.09 сек | Train Loss: 0.0007 | Train R²: 0.99 | Test Loss: 0.0050 | Test R²: 0.69
# Эпоха: 88 | Время: 13.04 сек | Train Loss: 0.0007 | Train R²: 0.99 | Test Loss: 0.0029 | Test R²: 0.82
# Эпоха: 89 | Время: 12.98 сек | Train Loss: 0.0006 | Train R²: 0.99 | Test Loss: 0.0029 | Test R²: 0.82
# Эпоха: 90 | Время: 13.09 сек | Train Loss: 0.0007 | Train R²: 0.99 | Test Loss: 0.0043 | Test R²: 0.74
# Эпоха: 91 | Время: 13.11 сек | Train Loss: 0.0008 | Train R²: 0.99 | Test Loss: 0.0035 | Test R²: 0.79
# Эпоха: 92 | Время: 13.03 сек | Train Loss: 0.0007 | Train R²: 0.99 | Test Loss: 0.0033 | Test R²: 0.80
# Эпоха: 93 | Время: 13.04 сек | Train Loss: 0.0007 | Train R²: 0.99 | Test Loss: 0.0034 | Test R²: 0.79
# Эпоха: 94 | Время: 13.16 сек | Train Loss: 0.0007 | Train R²: 0.99 | Test Loss: 0.0028 | Test R²: 0.83
# Эпоха: 95 | Время: 12.96 сек | Train Loss: 0.0006 | Train R²: 0.99 | Test Loss: 0.0026 | Test R²: 0.84
# Эпоха: 96 | Время: 13.03 сек | Train Loss: 0.0007 | Train R²: 0.99 | Test Loss: 0.0029 | Test R²: 0.82
# Эпоха: 97 | Время: 13.14 сек | Train Loss: 0.0007 | Train R²: 0.99 | Test Loss: 0.0033 | Test R²: 0.80
# Эпоха: 98 | Время: 13.07 сек | Train Loss: 0.0007 | Train R²: 0.99 | Test Loss: 0.0022 | Test R²: 0.87
# Эпоха: 99 | Время: 13.08 сек | Train Loss: 0.0007 | Train R²: 0.99 | Test Loss: 0.0030 | Test R²: 0.81
# Эпоха: 100 | Время: 13.04 сек | Train Loss: 0.0006 | Train R²: 0.99 | Test Loss: 0.0020 | Test R²: 0.88

# %%
model_param = {
    "model_state_dict": model.state_dict(),
    "input_size": 25,
    "hidden_size1": 48,
    "hidden_size2": 24,
    "fc_size": 16,
    "output_size": 1,
    "dropout_rate": 0.4
}
torch.save(model_param, "models/lstm_model_param_88.pth")
# Out:
# '\nmodel_param = {\n    "model_state_dict": model.state_dict(),\n    "input_size": 25,\n    "hidden_size1": 48,\n    "hidden_size2": 24,\n    "fc_size": 16,\n    "output_size": 1,\n    "dropout_rate": 0.4\n}\ntorch.save(model_param, "models/lstm_model_param_78.pth")'
